# %%
import matplotlib
# %matplotlib inline
import pandas as pd

# %%
import json

# %%
file_path = "201942_demar_derozan/game_data.json"
with open(file_path,'r') as infile:
    player_data = json.load(infile)
    print(player_data)
# Out:
# [{'SEASON_ID': '22018', 'Player_ID': 201942, 'Game_ID': '0021801227', 'GAME_DATE': 'APR 10, 2019', 'MATCHUP': 'SAS vs. DAL', 'WL': 'W', 'MIN': 34, 'FGM': 7, 'FGA': 15, 'FG_PCT': 0.467, 'FG3M': 0, 'FG3A': 1, 'FG3_PCT': 0.0, 'FTM': 5, 'FTA': 6, 'FT_PCT': 0.833, 'OREB': 1, 'DREB': 4, 'REB': 5, 'AST': 4, 'STL': 3, 'BLK': 0, 'TOV': 2, 'PF': 2, 'PTS': 19, 'PLUS_MINUS': 21, 'VIDEO_AVAILABLE': 1}, {'SEASON_ID': '22018', 'Player_ID': 201942, 'Game_ID': '0021801196', 'GAME_DATE': 'APR 07, 2019', 'MATCHUP': 'SAS @ CLE', 'WL': 'W', 'MIN': 32, 'FGM': 4, 'FGA': 9, 'FG_PCT': 0.444, 'FG3M': 0, 'FG3A': 0, 'FG3_PCT': 0.0, 'FTM': 6, 'FTA': 7, 'FT_PCT': 0.857, 'OREB': 0, 'DREB': 3, 'REB': 3, 'AST': 9, 'STL': 1, 'BLK': 0, 'TOV': 3, 'PF': 2, 'PTS': 14, 'PLUS_MINUS': 19, 'VIDEO_AVAILABLE': 1}, {'SEASON_ID': '22018', 'Player_ID': 201942, 'Game_ID': '0021801182', 'GAME_DATE': 'APR 05, 2019', 'MATCHUP': 'SAS @ WAS', 'WL': 'W', 'MIN': 28, 'FGM': 8, 'FGA': 14, 'FG_PCT': 0.571, 'FG3M': 0, 'FG3A': 0, 'FG3_PCT': 0
# ...

# %%
type(player_data)
# Out:
# list

# %%
player_data = pd.DataFrame(player_data)

# %%
player_data.columns
# Out:
# Index(['AST', 'BLK', 'DREB', 'FG3A', 'FG3M', 'FG3_PCT', 'FGA', 'FGM', 'FG_PCT',
#        'FTA', 'FTM', 'FT_PCT', 'GAME_DATE', 'Game_ID', 'MATCHUP', 'MIN',
#        'OREB', 'PF', 'PLUS_MINUS', 'PTS', 'Player_ID', 'REB', 'SEASON_ID',
#        'STL', 'TOV', 'VIDEO_AVAILABLE', 'WL'],
#       dtype='object')

# %%
player_data
# Out:
#      AST  BLK  DREB  FG3A  FG3M  FG3_PCT  FGA  FGM  FG_PCT  FTA ...  PF  \
# 0      4    0     4     1     0    0.000   15    7   0.467    6 ...   2
# 1      9    0     3     0     0    0.000    9    4   0.444    7 ...   2
# 2      4    0     3     0     0    0.000   14    8   0.571    0 ...   1
# 3      3    2     1     0     0    0.000    7    4   0.571    5 ...   1
# 4      7    0     7     0     0    0.000   11    7   0.636   16 ...   6
# 5      7    0     1     0     0    0.000   16    8   0.500    0 ...   4
# 6      8    0     1     0     0    0.000   12   10   0.833    5 ...   2
# 7      4    0     6     1     0    0.000   23   12   0.522    8 ...   2
# 8     11    2     0     0     0    0.000   18    8   0.444    0 ...   1
# 9      8    0     7     0     0    0.000   19    7   0.368    2 ...   5
# 10     6    1    15     1     0    0.000   12    6   0.500    6 ...   0
# 11     8    0     8     0     0    0.000   17    9   0.529    9 ...   0
# ...

# %%
player_data.plot(x="GAME_DATE", y='PTS')
