# %% [markdown]
# ### NBA STATS API:
#
# https://github.com/seemethere/nba_py/wiki/stats.nba.com-Endpoint-Documentation
#
# https://github.com/bttmly/nba/blob/master/doc/stats.md
#
# ### NBA DATA API
#
# http://nbasense.com/nba-api/
#
# http://data.nba.net/ Needs to target specific endpoint for up to date info

# %%
import requests
# Out:
# /home/tomi/.local/lib/python3.6/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.25.3) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'}
url = 'https://stats.nba.com/stats/playergamelog/?PlayerID=2544&Season=2016-17&SeasonType=Regular Season'

# %%
    nba = requests.get(url,headers=headers)

# %%
nbajson = nba.json()

# %%
nba
# Out:
# <Response [200]>

# %%
stats_endpoint = "stats.nba.com/stats/{endpoint}/?{params}"

# %%
r = requests.get("https://stats.nba.com/commonplayerinfo/?2544")

# %%
nbajson.keys()
# Out:
# dict_keys(['resource', 'parameters', 'resultSets'])

# %%
nbajson['resultSets']
# Out:
# [{'name': 'PlayerGameLog',
#   'headers': ['SEASON_ID',
#    'Player_ID',
#    'Game_ID',
#    'GAME_DATE',
#    'MATCHUP',
#    'WL',
#    'MIN',
#    'FGM',
#    'FGA',
#    'FG_PCT',
#    'FG3M',
#    'FG3A',
#    'FG3_PCT',
#    'FTM',
#    'FTA',
#    'FT_PCT',
#    'OREB',
#    'DREB',
#    'REB',
#    'AST',
#    'STL',
#    'BLK',
#    'TOV',
#    'PF',
#    'PTS',
#    'PLUS_MINUS',
#    'VIDEO_AVAILABLE'],
#   'rowSet': [['22016',
#     2544,
#     '0021601197',
#     'APR 09, 2017',
#     'CLE @ ATL',
#     'L',
#     47,
#     11,
#     21,
#     0.524,
#     1,
#     3,
#     0.333,
#     9,
#     10,
#     0.9,
#     3,
#     13,
#     16,
#     10,
#     1,
#     0,
#     3,
#     6,
#     32,
#     2,
#     1],
#    ['22016',
#     2544,
#     '0021601179',
#     'APR 07, 2017',
#     'CLE vs. ATL',
#     'L',
#     41,
#     12,
#     15,
#     0.8,
#     1,
#     2,
#     0.5,
#     2,
#     6,
#     0.333,
#     1,
#     7,
#     8,
#     7,
#     2,
#     0,
#     5,
#     0,
#     27,
#     -15,
#     1],
#    ['22016',
#     2544,
#     '0021601169',
#     'APR 05, 2017',
#     'CLE @ BOS',
#     'W',
#     39,
#     14,
#     22,
#     0.636,
#     1,
#     4,
#     0.25,
#     7,
#     7,
#     1.0,
#     2,
#     8,
#     10,
#     6,
#     1,
#     2,
#     3,
#     3,
#     36,
#     32,
#     1],
#    ['22016',
#     2544,
#     '0021601156',
#     'APR 04, 2017',
#     'CLE vs. ORL',
#     'W',
#     37,
#     7,
#     14,
#     0.5,
#     0,
#     3,
#     0.0,
#     4,
#     6,
#     0.667,
#     1,
#     10,
#     11,
#     11,
#     2,
#     1,
#     6,
#     2,
#     18,
#     17,
#     1],
#    ['22016',
#     2544,
#     '0021601150',
#     'APR 02, 2017',
#     'CLE vs. IND',
#     'W',
#     52,
#     16,
#     29,
#     0.552,
#     3,
#     10,
#     0.3,
#     6,
#     12,
#     0.5,
#     4,
#     10,
#     14,
#     11,
#     2,
#     1,
#     1,
#     4,
#     41,
#     -1,
#     1],
#    ['22016',
#     2544,
#     '0021601128',
#     'MAR 31, 2017',
#     'CLE vs. PHI',
#     'W',
#     30,
#     14,
#     22,
#     0.636,
#     3,
#     7,
#     0.429,
#     3,
#     6,
#     0.5,
#     2,
#     7,
#     9,
#     6,
#     0,
#     0,
#     2,
#     2,
#     34,
#     31,
#     1],
#    ['22016',
#     2544,
#     '0021601122',
#     'MAR 30, 2017',
#     'CLE @ CHI',
#     'L',
#     39,
#     11,
#     20,
#     0.55,
#     1,
#     7,
#     0.143,
#     3,
#     7,
#     0.429,
#     1,
#     9,
#     10,
#     8,
#     1,
#     1,
#     4,
#     0,
#     26,
#     -3,
#     1],
#    ['22016',
#     2544,
#     '0021601099',
#     'MAR 27, 2017',
#     'CLE @ SAS',
#     'L',
#     30,
#     7,
#     17,
#     0.412,
#     0,
#     3,
#     0.0,
#     3,
#     6,
#     0.5,
#     3,
#     5,
#     8,
#     8,
#     0,
#     0,
#     2,
#     3,
#     17,
#     -13,
#     1],
#    ['22016',
#     2544,
#     '0021601083',
#     'MAR 25, 2017',
#     'CLE vs. WAS',
#     'L',
#     41,
#     10,
#     21,
#     0.476,
#     0,
#     4,
#     0.0,
#     4,
#     6,
#     0.667,
#     3,
#     8,
#     11,
#     8,
#     0,
#     1,
#     3,
#     2,
#     24,
#     -11,
#     1],
#    ['22016',
#     2544,
#     '0021601073',
#     'MAR 24, 2017',
#     'CLE @ CHA',
#     'W',
#     40,
#     9,
#     14,
#     0.643,
#     0,
#     1,
#     0.0,
#     14,
#     16,
#     0.875,
#     0,
#     9,
#     9,
#     11,
#     1,
#     2,
#     4,
#     2,
#     32,
#     1,
#     1],
#    ['22016',
#     2544,
#     '0021601064',
#     'MAR 22, 2017',
#     'CLE @ DEN',
#     'L',
#     34,
#     8,
#     12,
#     0.667,
#     0,
#     2,
#     0.0,
#     2,
#     4,
#     0.5,
#     2,
#     4,
#     6,
#     5,
#     0,
#     0,
#     4,
#     1,
#     18,
#     -30,
#     1],
#    ['22016',
#     2544,
#     '0021601043',
#     'MAR 19, 2017',
#     'CLE @ LAL',
#     'W',
#     38,
#     13,
#     22,
#     0.591,
#     3,
#     8,
#     0.375,
#     5,
#     8,
#     0.625,
#     0,
#     6,
#     6,
#     7,
#     1,
#     0,
#     3,
#     2,
#     34,
#     12,
#     1],
#    ['22016',
#     2544,
#     '0021601014',
#     'MAR 16, 2017',
#     'CLE vs. UTA',
#     'W',
#     38,
#     13,
#     20,
#     0.65,
#     2,
#     5,
#     0.4,
#     5,
#     10,
#     0.5,
#     0,
#     10,
#     10,
#     6,
#     2,
#     1,
#     6,
#     0,
#     33,
#     14,
#     1],
#    ['22016',
#     2544,
#     '0021600999',
#     'MAR 14, 2017',
#     'CLE vs. DET',
#     'W',
#     28,
#     6,
#     12,
#     0.5,
#     0,
#     2,
#     0.0,
#     4,
#     5,
#     0.8,
#     0,
#     11,
#     11,
#     12,
#     0,
#     0,
#     2,
#     0,
#     16,
#     22,
#     1],
#    ['22016',
#     2544,
#     '0021600989',
#     'MAR 12, 2017',
#     'CLE @ HOU',
#     'L',
#     40,
#     12,
#     20,
#     0.6,
#     4,
#     11,
#     0.364,
#     2,
#     3,
#     0.667,
#     0,
#     7,
#     7,
#     5,
#     2,
#     0,
#     8,
#     2,
#     30,
#     -9,
#     1],
#    ['22016',
#     2544,
#     '0021600977',
#     'MAR 11, 2017',
#     'CLE @ ORL',
#     'W',
#     38,
#     8,
#     14,
#     0.571,
#     2,
#     5,
#     0.4,
#     6,
#     10,
#     0.6,
#     0,
#     12,
#     12,
#     12,
#     0,
#     1,
#     4,
#     3,
#     24,
#     12,
#     1],
#    ['22016',
#     2544,
#     '0021600960',
#     'MAR 09, 2017',
#     'CLE @ DET',
#     'L',
#     39,
#     12,
#     22,
#     0.545,
#     0,
#     6,
#     0.0,
#     5,
#     8,
#     0.625,
#     4,
#     10,
#     14,
#     10,
#     1,
#     0,
#     3,
#     1,
#     29,
#     18,
#     1],
#    ['22016',
#     2544,
#     '0021600936',
#     'MAR 06, 2017',
#     'CLE vs. MIA',
#     'L',
#     39,
#     11,
#     22,
#     0.5,
#     2,
#     5,
#     0.4,
#     6,
#     10,
#     0.6,
#     3,
#     14,
#     17,
#     6,
#     1,
#     1,
#     3,
#     2,
#     30,
#     14,
#     1],
#    ['22016',
#     2544,
#     '0021600913',
#     'MAR 03, 2017',
#     'CLE @ ATL',
#     'W',
#     39,
#     14,
#     27,
#     0.519,
#     6,
#     10,
#     0.6,
#     4,
#     8,
#     0.5,
#     1,
#     12,
#     13,
#     8,
#     0,
#     0,
#     2,
#     4,
#     38,
#     5,
#     1],
#    ['22016',
#     2544,
#     '0021600901',
#     'MAR 01, 2017',
#     'CLE @ BOS',
#     'L',
#     40,
#     10,
#     21,
#     0.476,
#     3,
#     6,
#     0.5,
#     5,
#     8,
#     0.625,
#     5,
#     8,
#     13,
#     10,
#     1,
#     1,
#     4,
#     3,
#     28,
#     -3,
#     1],
#    ['22016',
#     2544,
#     '0021600884',
#     'FEB 27, 2017',
#     'CLE vs. MIL',
#     'W',
#     37,
#     8,
#     12,
#     0.667,
#     1,
#     2,
#     0.5,
#     7,
#     9,
#     0.778,
#     0,
#     10,
#     10,
#     6,
#     0,
#     0,
#     3,
#     1,
#     24,
#     8,
#     1],
#    ['22016',
#     2544,
#     '0021600853',
#     'FEB 23, 2017',
#     'CLE vs. NYK',
#     'W',
#     37,
#     7,
#     11,
#     0.636,
#     0,
#     2,
#     0.0,
#     4,
#     6,
#     0.667,
#     0,
#     13,
#     13,
#     15,
#     0,
#     3,
#     6,
#     1,
#     18,
#     10,
#     1],
#    ['22016',
#     2544,
#     '0021600835',
#     'FEB 15, 2017',
#     'CLE vs. IND',
#     'W',
#     33,
#     12,
#     17,
#     0.706,
#     4,
#     5,
#     0.8,
#     3,
#     4,
#     0.75,
#     0,
#     5,
#     5,
#     4,
#     1,
#     0,
#     4,
#     2,
#     31,
#     9,
#     1],
#    ['22016',
#     2544,
#     '0021600832',
#     'FEB 14, 2017',
#     'CLE @ MIN',
#     'W',
#     40,
#     10,
#     14,
#     0.714,
#     2,
#     3,
#     0.667,
#     3,
#     6,
#     0.5,
#     1,
#     7,
#     8,
#     14,
#     0,
#     0,
#     6,
#     3,
#     25,
#     11,
#     1],
#    ['22016',
#     2544,
#     '0021600811',
#     'FEB 11, 2017',
#     'CLE vs. DEN',
#     'W',
#     33,
#     11,
#     16,
#     0.688,
#     1,
#     1,
#     1.0,
#     4,
#     4,
#     1.0,
#     0,
#     5,
#     5,
#     12,
#     2,
#     0,
#     6,
#     1,
#     27,
#     26,
#     1],
#    ['22016',
#     2544,
#     '0021600796',
#     'FEB 09, 2017',
#     'CLE @ OKC',
#     'L',
#     41,
#     8,
#     19,
#     0.421,
#     1,
#     4,
#     0.25,
#     1,
#     3,
#     0.333,
#     1,
#     4,
#     5,
#     7,
#     2,
#     2,
#     3,
#     1,
#     18,
#     -4,
#     1],
#    ['22016',
#     2544,
#     '0021600783',
#     'FEB 08, 2017',
#     'CLE @ IND',
#     'W',
#     38,
#     9,
#     16,
#     0.563,
#     1,
#     2,
#     0.5,
#     6,
#     8,
#     0.75,
#     1,
#     5,
#     6,
#     9,
#     1,
#     1,
#     4,
#     2,
#     25,
#     8,
#     1],
#    ['22016',
#     2544,
#     '0021600769',
#     'FEB 06, 2017',
#     'CLE @ WAS',
#     'W',
#     42,
#     12,
#     18,
#     0.667,
#     6,
#     8,
#     0.75,
#     2,
#     5,
#     0.4,
#     0,
#     7,
#     7,
#     17,
#     2,
#     2,
#     6,
#     6,
#     32,
#     0,
#     1],
#    ['22016',
#     2544,
#     '0021600759',
#     'FEB 04, 2017',
#     'CLE @ NYK',
#     'W',
#     40,
#     12,
#     20,
#     0.6,
#     4,
#     8,
#     0.5,
#     4,
#     5,
#     0.8,
#     0,
#     5,
#     5,
#     10,
#     0,
#     0,
#     5,
#     1,
#     32,
#     11,
#     1],
#    ['22016',
#     2544,
#     '0021600731',
#     'FEB 01, 2017',
#     'CLE vs. MIN',
#     'W',
#     34,
#     11,
#     14,
#     0.786,
#     1,
#     2,
#     0.5,
#     4,
#     7,
#     0.571,
#     0,
#     8,
#     8,
#     12,
#     2,
#     1,
#     2,
#     1,
#     27,
#     16,
#     1],
#    ['22016',
#     2544,
#     '0021600722',
#     'JAN 30, 2017',
#     'CLE @ DAL',
#     'L',
#     37,
#     9,
#     19,
#     0.474,
#     1,
#     6,
#     0.167,
#     4,
#     8,
#     0.5,
#     0,
#     9,
#     9,
#     9,
#     2,
#     0,
#     5,
#     0,
#     23,
#     -8,
#     1],
#    ['22016',
#     2544,
#     '0021600712',
#     'JAN 29, 2017',
#     'CLE vs. OKC',
#     'W',
#     37,
#     9,
#     18,
#     0.5,
#     0,
#     2,
#     0.0,
#     7,
#     10,
#     0.7,
#     1,
#     13,
#     14,
#     8,
#     1,
#     0,
#     2,
#     1,
#     25,
#     10,
#     1],
#    ['22016',
#     2544,
#     '0021600695',
#     'JAN 27, 2017',
#     'CLE vs. BKN',
#     'W',
#     34,
#     13,
#     18,
#     0.722,
#     1,
#     3,
#     0.333,
#     4,
#     7,
#     0.571,
#     0,
#     5,
#     5,
#     11,
#     0,
#     0,
#     5,
#     1,
#     31,
#     22,
#     1],
#    ['22016',
#     2544,
#     '0021600680',
#     'JAN 25, 2017',
#     'CLE vs. SAC',
#     'L',
#     45,
#     8,
#     15,
#     0.533,
#     0,
#     3,
#     0.0,
#     8,
#     11,
#     0.727,
#     4,
#     9,
#     13,
#     11,
#     2,
#     1,
#     5,
#     3,
#     24,
#     -1,
#     1],
#    ['22016',
#     2544,
#     '0021600671',
#     'JAN 23, 2017',
#     'CLE @ NOP',
#     'L',
#     44,
#     11,
#     21,
#     0.524,
#     1,
#     4,
#     0.25,
#     3,
#     4,
#     0.75,
#     2,
#     8,
#     10,
#     12,
#     2,
#     0,
#     6,
#     2,
#     26,
#     -11,
#     1],
#    ['22016',
#     2544,
#     '0021600657',
#     'JAN 21, 2017',
#     'CLE vs. SAS',
#     'L',
#     45,
#     11,
#     16,
#     0.688,
#     2,
#     5,
#     0.4,
#     5,
#     7,
#     0.714,
#     0,
#     6,
#     6,
#     7,
#     2,
#     0,
#     7,
#     5,
#     29,
#     -16,
#     1],
#    ['22016',
#     2544,
#     '0021600636',
#     'JAN 19, 2017',
#     'CLE vs. PHX',
#     'W',
#     39,
#     8,
#     12,
#     0.667,
#     0,
#     2,
#     0.0,
#     5,
#     8,
#     0.625,
#     0,
#     9,
#     9,
#     15,
#     1,
#     2,
#     4,
#     2,
#     21,
#     14,
#     1],
#    ['22016',
#     2544,
#     '0021600619',
#     'JAN 16, 2017',
#     'CLE @ GSW',
#     'L',
#     35,
#     6,
#     18,
#     0.333,
#     1,
#     4,
#     0.25,
#     7,
#     10,
#     0.7,
#     2,
#     6,
#     8,
#     2,
#     1,
#     0,
#     6,
#     1,
#     20,
#     -32,
#     1],
#    ['22016',
#     2544,
#     '0021600599',
#     'JAN 13, 2017',
#     'CLE @ SAC',
#     'W',
#     42,
#     6,
#     12,
#     0.5,
#     1,
#     4,
#     0.25,
#     3,
#     3,
#     1.0,
#     0,
#     2,
#     2,
#     15,
#     1,
#     1,
#     5,
#     2,
#     16,
#     16,
#     1],
#    ['22016',
#     2544,
#     '0021600585',
#     'JAN 11, 2017',
#     'CLE @ POR',
#     'L',
#     31,
#     5,
#     12,
#     0.417,
#     2,
#     5,
#     0.4,
#     8,
#     9,
#     0.889,
#     1,
#     10,
#     11,
#     4,
#     1,
#     1,
#     5,
#     1,
#     20,
#     -7,
#     1],
#    ['22016',
#     2544,
#     '0021600576',
#     'JAN 10, 2017',
#     'CLE @ UTA',
#     'L',
#     37,
#     10,
#     20,
#     0.5,
#     3,
#     6,
#     0.5,
#     6,
#     7,
#     0.857,
#     1,
#     5,
#     6,
#     5,
#     4,
#     0,
#     4,
#     0,
#     29,
#     -8,
#     1],
#    ['22016',
#     2544,
#     '0021600565',
#     'JAN 08, 2017',
#     'CLE @ PHX',
#     'W',
#     40,
#     11,
#     17,
#     0.647,
#     2,
#     4,
#     0.5,
#     4,
#     6,
#     0.667,
#     3,
#     5,
#     8,
#     4,
#     1,
#     0,
#     7,
#     3,
#     28,
#     -2,
#     1],
#    ['22016',
#     2544,
#     '0021600547',
#     'JAN 06, 2017',
#     'CLE @ BKN',
#     'W',
#     35,
#     14,
#     20,
#     0.7,
#     0,
#     1,
#     0.0,
#     8,
#     10,
#     0.8,
#     0,
#     9,
#     9,
#     6,
#     3,
#     0,
#     5,
#     2,
#     36,
#     20,
#     1],
#    ['22016',
#     2544,
#     '0021600532',
#     'JAN 04, 2017',
#     'CLE vs. CHI',
#     'L',
#     37,
#     12,
#     21,
#     0.571,
#     1,
#     2,
#     0.5,
#     6,
#     9,
#     0.667,
#     2,
#     6,
#     8,
#     7,
#     1,
#     0,
#     5,
#     2,
#     31,
#     -13,
#     1],
#    ['22016',
#     2544,
#     '0021600514',
#     'JAN 02, 2017',
#     'CLE vs. NOP',
#     'W',
#     39,
#     9,
#     21,
#     0.429,
#     0,
#     4,
#     0.0,
#     8,
#     10,
#     0.8,
#     2,
#     5,
#     7,
#     6,
#     2,
#     1,
#     4,
#     1,
#     26,
#     -4,
#     1],
#    ['22016',
#     2544,
#     '0021600505',
#     'DEC 31, 2016',
#     'CLE @ CHA',
#     'W',
#     36,
#     12,
#     25,
#     0.48,
#     4,
#     8,
#     0.5,
#     4,
#     6,
#     0.667,
#     2,
#     4,
#     6,
#     9,
#     1,
#     0,
#     1,
#     1,
#     32,
#     17,
#     1],
#    ['22016',
#     2544,
#     '0021600488',
#     'DEC 29, 2016',
#     'CLE vs. BOS',
#     'W',
#     44,
#     9,
#     18,
#     0.5,
#     2,
#     6,
#     0.333,
#     3,
#     7,
#     0.429,
#     2,
#     6,
#     8,
#     11,
#     1,
#     3,
#     8,
#     2,
#     23,
#     1,
#     1],
#    ['22016',
#     2544,
#     '0021600457',
#     'DEC 25, 2016',
#     'CLE vs. GSW',
#     'W',
#     40,
#     12,
#     22,
#     0.545,
#     4,
#     8,
#     0.5,
#     3,
#     7,
#     0.429,
#     5,
#     8,
#     13,
#     4,
#     2,
#     1,
#     5,
#     2,
#     31,
#     4,
#     1],
#    ['22016',
#     2544,
#     '0021600444',
#     'DEC 23, 2016',
#     'CLE vs. BKN',
#     'W',
#     27,
#     7,
#     16,
#     0.438,
#     0,
#     3,
#     0.0,
#     5,
#     6,
#     0.833,
#     1,
#     3,
#     4,
#     6,
#     3,
#     0,
#     1,
#     0,
#     19,
#     32,
#     1],
#    ['22016',
#     2544,
#     '0021600429',
#     'DEC 21, 2016',
#     'CLE vs. MIL',
#     'W',
#     34,
#     12,
#     24,
#     0.5,
#     4,
#     7,
#     0.571,
#     1,
#     1,
#     1.0,
#     1,
#     8,
#     9,
#     6,
#     0,
#     0,
#     2,
#     0,
#     29,
#     26,
#     1],
#    ['22016',
#     2544,
#     '0021600423',
#     'DEC 20, 2016',
#     'CLE @ MIL',
#     'W',
#     47,
#     12,
#     25,
#     0.48,
#     5,
#     9,
#     0.556,
#     5,
#     6,
#     0.833,
#     3,
#     9,
#     12,
#     7,
#     1,
#     1,
#     2,
#     2,
#     34,
#     8,
#     1],
#    ['22016',
#     2544,
#     '0021600402',
#     'DEC 17, 2016',
#     'CLE vs. LAL',
#     'W',
#     39,
#     9,
#     18,
#     0.5,
#     2,
#     5,
#     0.4,
#     6,
#     11,
#     0.545,
#     1,
#     6,
#     7,
#     9,
#     2,
#     2,
#     2,
#     1,
#     26,
#     17,
#     1],
#    ['22016',
#     2544,
#     '0021600368',
#     'DEC 13, 2016',
#     'CLE vs. MEM',
#     'W',
#     36,
#     9,
#     17,
#     0.529,
#     0,
#     4,
#     0.0,
#     5,
#     8,
#     0.625,
#     1,
#     5,
#     6,
#     8,
#     3,
#     0,
#     6,
#     1,
#     23,
#     8,
#     1],
#    ['22016',
#     2544,
#     '0021600349',
#     'DEC 10, 2016',
#     'CLE vs. CHA',
#     'W',
#     42,
#     17,
#     24,
#     0.708,
#     5,
#     10,
#     0.5,
#     5,
#     9,
#     0.556,
#     1,
#     8,
#     9,
#     10,
#     3,
#     1,
#     5,
#     3,
#     44,
#     -1,
#     1],
#    ['22016',
#     2544,
#     '0021600338',
#     'DEC 09, 2016',
#     'CLE vs. MIA',
#     'W',
#     37,
#     12,
#     22,
#     0.545,
#     1,
#     3,
#     0.333,
#     2,
#     4,
#     0.5,
#     2,
#     6,
#     8,
#     8,
#     3,
#     0,
#     3,
#     2,
#     27,
#     22,
#     1],
#    ['22016',
#     2544,
#     '0021600327',
#     'DEC 07, 2016',
#     'CLE @ NYK',
#     'W',
#     32,
#     7,
#     10,
#     0.7,
#     1,
#     2,
#     0.5,
#     10,
#     14,
#     0.714,
#     2,
#     4,
#     6,
#     7,
#     1,
#     2,
#     4,
#     2,
#     25,
#     32,
#     1],
#    ['22016',
#     2544,
#     '0021600305',
#     'DEC 05, 2016',
#     'CLE @ TOR',
#     'W',
#     42,
#     12,
#     26,
#     0.462,
#     2,
#     7,
#     0.286,
#     8,
#     9,
#     0.889,
#     3,
#     5,
#     8,
#     7,
#     2,
#     0,
#     1,
#     2,
#     34,
#     9,
#     1],
#    ['22016',
#     2544,
#     '0021600286',
#     'DEC 02, 2016',
#     'CLE @ CHI',
#     'L',
#     45,
#     13,
#     22,
#     0.591,
#     1,
#     3,
#     0.333,
#     0,
#     0,
#     0.0,
#     0,
#     5,
#     5,
#     13,
#     0,
#     0,
#     8,
#     2,
#     27,
#     -2,
#     1],
#    ['22016',
#     2544,
#     '0021600279',
#     'DEC 01, 2016',
#     'CLE vs. LAC',
#     'L',
#     34,
#     5,
#     14,
#     0.357,
#     0,
#     2,
#     0.0,
#     6,
#     11,
#     0.545,
#     1,
#     4,
#     5,
#     5,
#     2,
#     0,
#     5,
#     2,
#     16,
#     -20,
#     1],
#    ['22016',
#     2544,
#     '0021600262',
#     'NOV 29, 2016',
#     'CLE @ MIL',
#     'L',
#     33,
#     8,
#     16,
#     0.5,
#     3,
#     8,
#     0.375,
#     3,
#     7,
#     0.429,
#     0,
#     4,
#     4,
#     4,
#     0,
#     0,
#     7,
#     3,
#     22,
#     -12,
#     1],
#    ['22016',
#     2544,
#     '0021600245',
#     'NOV 27, 2016',
#     'CLE @ PHI',
#     'W',
#     42,
#     9,
#     19,
#     0.474,
#     1,
#     4,
#     0.25,
#     7,
#     9,
#     0.778,
#     2,
#     8,
#     10,
#     13,
#     1,
#     0,
#     5,
#     0,
#     26,
#     2,
#     1],
#    ['22016',
#     2544,
#     '0021600227',
#     'NOV 25, 2016',
#     'CLE vs. DAL',
#     'W',
#     29,
#     6,
#     13,
#     0.462,
#     2,
#     5,
#     0.4,
#     5,
#     5,
#     1.0,
#     0,
#     5,
#     5,
#     11,
#     1,
#     0,
#     4,
#     1,
#     19,
#     33,
#     1],
#    ['22016',
#     2544,
#     '0021600215',
#     'NOV 23, 2016',
#     'CLE vs. POR',
#     'W',
#     38,
#     11,
#     21,
#     0.524,
#     2,
#     3,
#     0.667,
#     7,
#     8,
#     0.875,
#     1,
#     9,
#     10,
#     13,
#     3,
#     0,
#     3,
#     0,
#     31,
#     17,
#     1],
#    ['22016',
#     2544,
#     '0021600175',
#     'NOV 18, 2016',
#     'CLE vs. DET',
#     'W',
#     28,
#     9,
#     14,
#     0.643,
#     1,
#     3,
#     0.333,
#     2,
#     3,
#     0.667,
#     0,
#     3,
#     3,
#     3,
#     0,
#     1,
#     2,
#     1,
#     21,
#     21,
#     1],
#    ['22016',
#     2544,
#     '0021600153',
#     'NOV 15, 2016',
#     'CLE vs. TOR',
#     'W',
#     38,
#     10,
#     15,
#     0.667,
#     2,
#     5,
#     0.4,
#     6,
#     10,
#     0.6,
#     0,
#     9,
#     9,
#     15,
#     1,
#     0,
#     5,
#     2,
#     28,
#     1,
#     1],
#    ['22016',
#     2544,
#     '0021600140',
#     'NOV 13, 2016',
#     'CLE vs. CHA',
#     'W',
#     39,
#     8,
#     21,
#     0.381,
#     2,
#     5,
#     0.4,
#     1,
#     2,
#     0.5,
#     0,
#     8,
#     8,
#     8,
#     1,
#     1,
#     3,
#     0,
#     19,
#     12,
#     1],
#    ['22016',
#     2544,
#     '0021600122',
#     'NOV 11, 2016',
#     'CLE @ WAS',
#     'W',
#     38,
#     9,
#     18,
#     0.5,
#     3,
#     4,
#     0.75,
#     6,
#     9,
#     0.667,
#     0,
#     10,
#     10,
#     5,
#     2,
#     2,
#     6,
#     1,
#     27,
#     7,
#     1],
#    ['22016',
#     2544,
#     '0021600100',
#     'NOV 08, 2016',
#     'CLE vs. ATL',
#     'L',
#     37,
#     8,
#     17,
#     0.471,
#     2,
#     5,
#     0.4,
#     5,
#     5,
#     1.0,
#     2,
#     7,
#     9,
#     5,
#     3,
#     0,
#     1,
#     3,
#     23,
#     7,
#     1],
#    ['22016',
#     2544,
#     '0021600080',
#     'NOV 05, 2016',
#     'CLE @ PHI',
#     'W',
#     36,
#     9,
#     23,
#     0.391,
#     1,
#     5,
#     0.2,
#     6,
#     7,
#     0.857,
#     1,
#     7,
#     8,
#     14,
#     2,
#     1,
#     5,
#     1,
#     25,
#     11,
#     1],
#    ['22016',
#     2544,
#     '0021600068',
#     'NOV 03, 2016',
#     'CLE vs. BOS',
#     'W',
#     36,
#     12,
#     22,
#     0.545,
#     1,
#     4,
#     0.25,
#     5,
#     5,
#     1.0,
#     1,
#     6,
#     7,
#     12,
#     1,
#     0,
#     2,
#     2,
#     30,
#     18,
#     1],
#    ['22016',
#     2544,
#     '0021600047',
#     'NOV 01, 2016',
#     'CLE vs. HOU',
#     'W',
#     36,
#     6,
#     12,
#     0.5,
#     1,
#     3,
#     0.333,
#     6,
#     10,
#     0.6,
#     3,
#     10,
#     13,
#     8,
#     0,
#     0,
#     4,
#     4,
#     19,
#     15,
#     1],
#    ['22016',
#     2544,
#     '0021600029',
#     'OCT 29, 2016',
#     'CLE vs. ORL',
#     'W',
#     39,
#     7,
#     16,
#     0.438,
#     2,
#     6,
#     0.333,
#     7,
#     11,
#     0.636,
#     1,
#     5,
#     6,
#     9,
#     1,
#     1,
#     2,
#     2,
#     23,
#     1,
#     1],
#    ['22016',
#     2544,
#     '0021600018',
#     'OCT 28, 2016',
#     'CLE @ TOR',
#     'W',
#     39,
#     7,
#     16,
#     0.438,
#     2,
#     6,
#     0.333,
#     5,
#     7,
#     0.714,
#     2,
#     6,
#     8,
#     7,
#     0,
#     0,
#     5,
#     2,
#     21,
#     0,
#     1],
#    ['22016',
#     2544,
#     '0021600001',
#     'OCT 25, 2016',
#     'CLE vs. NYK',
#     'W',
#     32,
#     9,
#     14,
#     0.643,
#     0,
#     3,
#     0.0,
#     1,
#     2,
#     0.5,
#     3,
#     8,
#     11,
#     14,
#     0,
#     1,
#     4,
#     3,
#     19,
#     26,
#     1]]}]

# %%
for i in nbajson['resultSets'][0]["rowSet"]:
    print(i[2])
    print("-----------------------------------------------------------------------------------")
# Out:
# 0021601197
# -----------------------------------------------------------------------------------
# 0021601179
# -----------------------------------------------------------------------------------
# 0021601169
# -----------------------------------------------------------------------------------
# 0021601156
# -----------------------------------------------------------------------------------
# 0021601150
# -----------------------------------------------------------------------------------
# 0021601128
# -----------------------------------------------------------------------------------
# 0021601122
# -----------------------------------------------------------------------------------
# 0021601099
# -----------------------------------------------------------------------------------
# 0021601083
# -----------------------------------------------------------------------------------
# 0021601073
# -----------------------------------------------------------------------------------
# 0021601064
# -----------------------------------------------------------------------------------
# 0021601043
# -----------------------------------------------------------------------------------
# 0021601014
# -----------------------------------------------------------------------------------
# 0021600999
# -----------------------------------------------------------------------------------
# 0021600989
# -----------------------------------------------------------------------------------
# 0021600977
# -----------------------------------------------------------------------------------
# 0021600960
# -----------------------------------------------------------------------------------
# 0021600936
# -----------------------------------------------------------------------------------
# 0021600913
# -----------------------------------------------------------------------------------
# 0021600901
# -----------------------------------------------------------------------------------
# 0021600884
# -----------------------------------------------------------------------------------
# 0021600853
# -----------------------------------------------------------------------------------
# 0021600835
# -----------------------------------------------------------------------------------
# 0021600832
# -----------------------------------------------------------------------------------
# 0021600811
# -----------------------------------------------------------------------------------
# 0021600796
# -----------------------------------------------------------------------------------
# 0021600783
# -----------------------------------------------------------------------------------
# 0021600769
# -----------------------------------------------------------------------------------
# 0021600759
# -----------------------------------------------------------------------------------
# 0021600731
# -----------------------------------------------------------------------------------
# 0021600722
# -----------------------------------------------------------------------------------
# 0021600712
# -----------------------------------------------------------------------------------
# 0021600695
# -----------------------------------------------------------------------------------
# 0021600680
# -----------------------------------------------------------------------------------
# 0021600671
# -----------------------------------------------------------------------------------
# 0021600657
# -----------------------------------------------------------------------------------
# 0021600636
# -----------------------------------------------------------------------------------
# 0021600619
# -----------------------------------------------------------------------------------
# 0021600599
# -----------------------------------------------------------------------------------
# 0021600585
# -----------------------------------------------------------------------------------
# 0021600576
# -----------------------------------------------------------------------------------
# 0021600565
# -----------------------------------------------------------------------------------
# 0021600547
# -----------------------------------------------------------------------------------
# 0021600532
# -----------------------------------------------------------------------------------
# 0021600514
# -----------------------------------------------------------------------------------
# 0021600505
# -----------------------------------------------------------------------------------
# 0021600488
# -----------------------------------------------------------------------------------
# 0021600457
# -----------------------------------------------------------------------------------
# 0021600444
# -----------------------------------------------------------------------------------
# 0021600429
# -----------------------------------------------------------------------------------
# 0021600423
# -----------------------------------------------------------------------------------
# 0021600402
# -----------------------------------------------------------------------------------
# 0021600368
# -----------------------------------------------------------------------------------
# 0021600349
# -----------------------------------------------------------------------------------
# 0021600338
# -----------------------------------------------------------------------------------
# 0021600327
# -----------------------------------------------------------------------------------
# 0021600305
# -----------------------------------------------------------------------------------
# 0021600286
# -----------------------------------------------------------------------------------
# 0021600279
# -----------------------------------------------------------------------------------
# 0021600262
# -----------------------------------------------------------------------------------
# 0021600245
# -----------------------------------------------------------------------------------
# 0021600227
# -----------------------------------------------------------------------------------
# 0021600215
# -----------------------------------------------------------------------------------
# 0021600175
# -----------------------------------------------------------------------------------
# 0021600153
# -----------------------------------------------------------------------------------
# 0021600140
# -----------------------------------------------------------------------------------
# 0021600122
# -----------------------------------------------------------------------------------
# 0021600100
# -----------------------------------------------------------------------------------
# 0021600080
# -----------------------------------------------------------------------------------
# 0021600068
# -----------------------------------------------------------------------------------
# 0021600047
# -----------------------------------------------------------------------------------
# 0021600029
# -----------------------------------------------------------------------------------
# 0021600018
# -----------------------------------------------------------------------------------
# 0021600001
# -----------------------------------------------------------------------------------

# %%
len(nbajson['resultSets'][0]["rowSet"])
# Out:
# 74

# %%
nbaData = requests.get("http://data.nba.net/10s/prod/v1/2019/players.json")

# %%
nbaData
# Out:
# <Response [200]>

# %%
nbaDataJSON = nbaData.json()

# %%
nbaDataJSON["league"]["standard"]
# Out:
# [{'firstName': 'Jalen',
#   'lastName': 'Adams',
#   'temporaryDisplayName': 'Adams, Jalen',
#   'personId': '1629824',
#   'teamId': '1610612740',
#   'jersey': '6',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '3',
#   'heightMeters': '1.9',
#   'weightPounds': '195',
#   'weightKilograms': '88.5',
#   'dateOfBirthUTC': '1995-12-11',
#   'teamSitesOnly': {'playerCode': 'jalen_adams',
#    'posFull': 'Guard',
#    'displayAffiliation': 'Connecticut/USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612740',
#     'seasonStart': '2019',
#     'seasonEnd': '2019'}],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '0',
#   'collegeName': 'Connecticut',
#   'lastAffiliation': 'Connecticut/USA',
#   'country': 'USA'},
#  {'firstName': 'Steven',
#   'lastName': 'Adams',
#   'temporaryDisplayName': 'Adams, Steven',
#   'personId': '203500',
#   'teamId': '1610612760',
#   'jersey': '12',
#   'isActive': True,
#   'pos': 'C',
#   'heightFeet': '7',
#   'heightInches': '0',
#   'heightMeters': '2.13',
#   'weightPounds': '265',
#   'weightKilograms': '120.2',
#   'dateOfBirthUTC': '1993-07-20',
#   'teamSitesOnly': {'playerCode': 'steven_adams',
#    'posFull': 'Center',
#    'displayAffiliation': 'Pittsburgh/New Zealand',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612760',
#     'seasonStart': '2013',
#     'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612760',
#    'pickNum': '12',
#    'roundNum': '1',
#    'seasonYear': '2013'},
#   'nbaDebutYear': '2013',
#   'yearsPro': '6',
#   'collegeName': 'Pittsburgh',
#   'lastAffiliation': 'Pittsburgh/New Zealand',
#   'country': 'New Zealand'},
#  {'firstName': 'Bam',
#   'lastName': 'Adebayo',
#   'temporaryDisplayName': 'Adebayo, Bam',
#   'personId': '1628389',
#   'teamId': '1610612748',
#   'jersey': '13',
#   'isActive': True,
#   'pos': 'C-F',
#   'heightFeet': '6',
#   'heightInches': '10',
#   'heightMeters': '2.08',
#   'weightPounds': '255',
#   'weightKilograms': '115.7',
#   'dateOfBirthUTC': '1997-07-18',
#   'teamSitesOnly': {'playerCode': 'bam_adebayo',
#    'posFull': 'Center-Forward',
#    'displayAffiliation': 'Kentucky/USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612748',
#     'seasonStart': '2017',
#     'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612748',
#    'pickNum': '14',
#    'roundNum': '1',
#    'seasonYear': '2017'},
#   'nbaDebutYear': '2017',
#   'yearsPro': '2',
#   'collegeName': 'Kentucky',
#   'lastAffiliation': 'Kentucky/USA',
#   'country': 'USA'},
#  {'firstName': 'Deng',
#   'lastName': 'Adel',
#   'temporaryDisplayName': 'Adel, Deng',
#   'personId': '1629061',
#   'teamId': '1610612751',
#   'jersey': '10',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '7',
#   'heightMeters': '2.01',
#   'weightPounds': '196',
#   'weightKilograms': '88.9',
#   'dateOfBirthUTC': '1997-02-01',
#   'teamSitesOnly': {'playerCode': 'deng_adel',
#    'posFull': 'Forward',
#    'displayAffiliation': 'Louisville/South Sudan',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612739',
#     'seasonStart': '2018',
#     'seasonEnd': '2018'},
#    {'teamId': '1610612751', 'seasonStart': '2019', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '2018',
#   'yearsPro': '1',
#   'collegeName': 'Louisville',
#   'lastAffiliation': ' South Sudan/South Sudan',
#   'country': 'South Sudan'},
#  {'firstName': 'DeVaughn',
#   'lastName': 'Akoon-Purcell',
#   'temporaryDisplayName': 'Akoon-Purcell, DeVaughn',
#   'personId': '1629152',
#   'teamId': '1610612760',
#   'jersey': '44',
#   'isActive': True,
#   'pos': 'G-F',
#   'heightFeet': '6',
#   'heightInches': '6',
#   'heightMeters': '1.98',
#   'weightPounds': '200',
#   'weightKilograms': '90.7',
#   'dateOfBirthUTC': '1993-06-05',
#   'teamSitesOnly': {'playerCode': 'devaughn_akoon-purcell',
#    'posFull': 'Guard-Forward',
#    'displayAffiliation': 'Illinois State/USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612743',
#     'seasonStart': '2018',
#     'seasonEnd': '2018'},
#    {'teamId': '1610612760', 'seasonStart': '2019', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '2018',
#   'yearsPro': '1',
#   'collegeName': 'Illinois State',
#   'lastAffiliation': 'Illinois State/Trinidad and Tobago',
#   'country': 'Trinidad and Tobago'},
#  {'firstName': 'LaMarcus',
#   'lastName': 'Aldridge',
#   'temporaryDisplayName': 'Aldridge, LaMarcus',
#   'personId': '200746',
#   'teamId': '1610612759',
#   'jersey': '12',
#   'isActive': True,
#   'pos': 'C-F',
#   'heightFeet': '6',
#   'heightInches': '11',
#   'heightMeters': '2.11',
#   'weightPounds': '260',
#   'weightKilograms': '117.9',
#   'dateOfBirthUTC': '1985-07-19',
#   'teamSitesOnly': {'playerCode': 'lamarcus_aldridge',
#    'posFull': 'Center-Forward',
#    'displayAffiliation': 'Texas/USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612757',
#     'seasonStart': '2006',
#     'seasonEnd': '2014'},
#    {'teamId': '1610612759', 'seasonStart': '2015', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612741',
#    'pickNum': '2',
#    'roundNum': '1',
#    'seasonYear': '2006'},
#   'nbaDebutYear': '2006',
#   'yearsPro': '13',
#   'collegeName': 'Texas',
#   'lastAffiliation': 'Texas/USA',
#   'country': 'USA'},
#  {'firstName': 'Kyle',
#   'lastName': 'Alexander',
#   'temporaryDisplayName': 'Alexander, Kyle',
#   'personId': '1629734',
#   'teamId': '1610612748',
#   'jersey': '17',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '11',
#   'heightMeters': '2.11',
#   'weightPounds': '225',
#   'weightKilograms': '102.1',
#   'dateOfBirthUTC': '1996-10-21',
#   'teamSitesOnly': {'playerCode': 'kyle_alexander',
#    'posFull': 'Forward',
#    'displayAffiliation': 'Tennessee/Canada',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612748',
#     'seasonStart': '2019',
#     'seasonEnd': '2019'}],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '0',
#   'collegeName': 'Tennessee',
#   'lastAffiliation': 'Tennessee/Canada',
#   'country': 'Canada'},
#  {'firstName': 'Nickeil',
#   'lastName': 'Alexander-Walker',
#   'temporaryDisplayName': 'Alexander-Walker, Nickeil',
#   'personId': '1629638',
#   'teamId': '1610612740',
#   'jersey': '0',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '5',
#   'heightMeters': '1.96',
#   'weightPounds': '205',
#   'weightKilograms': '93.0',
#   'dateOfBirthUTC': '1998-09-02',
#   'teamSitesOnly': {'playerCode': 'nickeil_alexander-walker',
#    'posFull': 'Guard',
#    'displayAffiliation': 'Virginia Tech/Canada',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612740',
#     'seasonStart': '2019',
#     'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612751',
#    'pickNum': '17',
#    'roundNum': '1',
#    'seasonYear': '2019'},
#   'nbaDebutYear': '',
#   'yearsPro': '0',
#   'collegeName': 'Virginia Tech',
#   'lastAffiliation': ' Canada/Canada',
#   'country': 'Canada'},
#  {'firstName': 'Grayson',
#   'lastName': 'Allen',
#   'temporaryDisplayName': 'Allen, Grayson',
#   'personId': '1628960',
#   'teamId': '1610612763',
#   'jersey': '3',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '5',
#   'heightMeters': '1.96',
#   'weightPounds': '198',
#   'weightKilograms': '89.8',
#   'dateOfBirthUTC': '1995-10-08',
#   'teamSitesOnly': {'playerCode': 'grayson_allen',
#    'posFull': 'Guard',
#    'displayAffiliation': 'Duke/USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612762',
#     'seasonStart': '2018',
#     'seasonEnd': '2018'},
#    {'teamId': '1610612763', 'seasonStart': '2019', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612762',
#    'pickNum': '21',
#    'roundNum': '1',
#    'seasonYear': '2018'},
#   'nbaDebutYear': '2018',
#   'yearsPro': '1',
#   'collegeName': 'Duke',
#   'lastAffiliation': 'Duke University/USA',
#   'country': 'USA'},
#  {'firstName': 'Jarrett',
#   'lastName': 'Allen',
#   'temporaryDisplayName': 'Allen, Jarrett',
#   'personId': '1628386',
#   'teamId': '1610612751',
#   'jersey': '31',
#   'isActive': True,
#   'pos': 'C',
#   'heightFeet': '6',
#   'heightInches': '11',
#   'heightMeters': '2.11',
#   'weightPounds': '243',
#   'weightKilograms': '110.2',
#   'dateOfBirthUTC': '1998-04-21',
#   'teamSitesOnly': {'playerCode': 'jarrett_allen',
#    'posFull': 'Center',
#    'displayAffiliation': 'Texas/USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612751',
#     'seasonStart': '2017',
#     'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612751',
#    'pickNum': '22',
#    'roundNum': '1',
#    'seasonYear': '2017'},
#   'nbaDebutYear': '2017',
#   'yearsPro': '2',
#   'collegeName': 'Texas',
#   'lastAffiliation': 'Texas/USA',
#   'country': 'USA'},
#  {'firstName': 'Kadeem',
#   'lastName': 'Allen',
#   'temporaryDisplayName': 'Allen, Kadeem',
#   'personId': '1628443',
#   'teamId': '1610612752',
#   'jersey': '0',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '3',
#   'heightMeters': '1.9',
#   'weightPounds': '200',
#   'weightKilograms': '90.7',
#   'dateOfBirthUTC': '1993-01-15',
#   'teamSitesOnly': {'playerCode': 'kadeem_allen',
#    'posFull': 'Guard',
#    'displayAffiliation': 'Arizona/USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612738',
#     'seasonStart': '2017',
#     'seasonEnd': '2017'},
#    {'teamId': '1610612752', 'seasonStart': '2018', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612738',
#    'pickNum': '53',
#    'roundNum': '2',
#    'seasonYear': '2017'},
#   'nbaDebutYear': '2017',
#   'yearsPro': '2',
#   'collegeName': 'Arizona',
#   'lastAffiliation': 'ArizonaUSA/USA',
#   'country': 'USA'},
#  {'firstName': 'Al-Farouq',
#   'lastName': 'Aminu',
#   'temporaryDisplayName': 'Aminu, Al-Farouq',
#   'personId': '202329',
#   'teamId': '1610612753',
#   'jersey': '2',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '9',
#   'heightMeters': '2.06',
#   'weightPounds': '220',
#   'weightKilograms': '99.8',
#   'dateOfBirthUTC': '1990-09-21',
#   'teamSitesOnly': {'playerCode': 'al-farouq_aminu',
#    'posFull': 'Forward',
#    'displayAffiliation': 'Wake Forest/USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612746',
#     'seasonStart': '2010',
#     'seasonEnd': '2010'},
#    {'teamId': '1610612740', 'seasonStart': '2011', 'seasonEnd': '2013'},
#    {'teamId': '1610612742', 'seasonStart': '2014', 'seasonEnd': '2014'},
#    {'teamId': '1610612757', 'seasonStart': '2015', 'seasonEnd': '2018'},
#    {'teamId': '1610612753', 'seasonStart': '2019', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612746',
#    'pickNum': '8',
#    'roundNum': '1',
#    'seasonYear': '2010'},
#   'nbaDebutYear': '2010',
#   'yearsPro': '9',
#   'collegeName': 'Wake Forest',
#   'lastAffiliation': 'Wake Forest/USA',
#   'country': 'USA'},
#  {'firstName': 'Justin',
#   'lastName': 'Anderson',
#   'temporaryDisplayName': 'Anderson, Justin',
#   'personId': '1626147',
#   'teamId': '1610612764',
#   'jersey': '7',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '6',
#   'heightMeters': '1.98',
#   'weightPounds': '230',
#   'weightKilograms': '104.3',
#   'dateOfBirthUTC': '1993-11-19',
#   'teamSitesOnly': {'playerCode': 'justin_anderson',
#    'posFull': 'Forward',
#    'displayAffiliation': 'Virginia/USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612742',
#     'seasonStart': '2015',
#     'seasonEnd': '2016'},
#    {'teamId': '1610612755', 'seasonStart': '2016', 'seasonEnd': '2017'},
#    {'teamId': '1610612737', 'seasonStart': '2018', 'seasonEnd': '2018'},
#    {'teamId': '1610612764', 'seasonStart': '2019', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612742',
#    'pickNum': '21',
#    'roundNum': '1',
#    'seasonYear': '2015'},
#   'nbaDebutYear': '2015',
#   'yearsPro': '4',
#   'collegeName': 'Virginia',
#   'lastAffiliation': 'Virginia/USA',
#   'country': 'USA'},
#  {'firstName': 'Kyle',
#   'lastName': 'Anderson',
#   'temporaryDisplayName': 'Anderson, Kyle',
#   'personId': '203937',
#   'teamId': '1610612763',
#   'jersey': '1',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '9',
#   'heightMeters': '2.06',
#   'weightPounds': '230',
#   'weightKilograms': '104.3',
#   'dateOfBirthUTC': '1993-09-20',
#   'teamSitesOnly': {'playerCode': 'kyle_anderson',
#    'posFull': 'Forward',
#    'displayAffiliation': 'UCLA/USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612759',
#     'seasonStart': '2014',
#     'seasonEnd': '2017'},
#    {'teamId': '1610612763', 'seasonStart': '2018', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612759',
#    'pickNum': '30',
#    'roundNum': '1',
#    'seasonYear': '2014'},
#   'nbaDebutYear': '2014',
#   'yearsPro': '5',
#   'collegeName': 'UCLA',
#   'lastAffiliation': 'UCLA/USA',
#   'country': 'USA'},
#  {'firstName': 'Ryan',
#   'lastName': 'Anderson',
#   'temporaryDisplayName': 'Anderson, Ryan',
#   'personId': '201583',
#   'teamId': '1610612745',
#   'jersey': '33',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '10',
#   'heightMeters': '2.08',
#   'weightPounds': '240',
#   'weightKilograms': '108.9',
#   'dateOfBirthUTC': '1988-05-06',
#   'teamSitesOnly': {'playerCode': 'ryan_anderson',
#    'posFull': 'Forward',
#    'displayAffiliation': 'California/USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612751',
#     'seasonStart': '2008',
#     'seasonEnd': '2008'},
#    {'teamId': '1610612753', 'seasonStart': '2009', 'seasonEnd': '2011'},
#    {'teamId': '1610612740', 'seasonStart': '2012', 'seasonEnd': '2015'},
#    {'teamId': '1610612745', 'seasonStart': '2016', 'seasonEnd': '2017'},
#    {'teamId': '1610612756', 'seasonStart': '2018', 'seasonEnd': '2018'},
#    {'teamId': '1610612748', 'seasonStart': '2018', 'seasonEnd': '2018'},
#    {'teamId': '1610612745', 'seasonStart': '2019', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612751',
#    'pickNum': '21',
#    'roundNum': '1',
#    'seasonYear': '2008'},
#   'nbaDebutYear': '2008',
#   'yearsPro': '11',
#   'collegeName': 'California',
#   'lastAffiliation': 'California/USA',
#   'country': 'USA'},
#  {'firstName': 'Giannis',
#   'lastName': 'Antetokounmpo',
#   'temporaryDisplayName': 'Antetokounmpo, Giannis',
#   'personId': '203507',
#   'teamId': '1610612749',
#   'jersey': '34',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '11',
#   'heightMeters': '2.11',
#   'weightPounds': '242',
#   'weightKilograms': '109.8',
#   'dateOfBirthUTC': '1994-12-06',
#   'teamSitesOnly': {'playerCode': 'giannis_antetokounmpo',
#    'posFull': 'Forward',
#    'displayAffiliation': 'Greece',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612749',
#     'seasonStart': '2013',
#     'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612749',
#    'pickNum': '15',
#    'roundNum': '1',
#    'seasonYear': '2013'},
#   'nbaDebutYear': '2013',
#   'yearsPro': '6',
#   'collegeName': ' ',
#   'lastAffiliation': 'Greece/Greece',
#   'country': 'Greece'},
#  {'firstName': 'Kostas',
#   'lastName': 'Antetokounmpo',
#   'temporaryDisplayName': 'Antetokounmpo, Kostas',
#   'personId': '1628961',
#   'teamId': '1610612747',
#   'jersey': '37',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '10',
#   'heightMeters': '2.08',
#   'weightPounds': '200',
#   'weightKilograms': '90.7',
#   'dateOfBirthUTC': '1997-11-20',
#   'teamSitesOnly': {'playerCode': 'kostas_antetokounmpo',
#    'posFull': 'Forward',
#    'displayAffiliation': 'Dayton/Greece',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612742',
#     'seasonStart': '2018',
#     'seasonEnd': '2018'},
#    {'teamId': '1610612747', 'seasonStart': '2019', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612755',
#    'pickNum': '60',
#    'roundNum': '2',
#    'seasonYear': '2018'},
#   'nbaDebutYear': '2018',
#   'yearsPro': '1',
#   'collegeName': 'University of Dayton',
#   'lastAffiliation': 'University of Dayton/Greece',
#   'country': 'Greece'},
#  {'firstName': 'Thanasis',
#   'lastName': 'Antetokounmpo',
#   'temporaryDisplayName': 'Antetokounmpo, Thanasis',
#   'personId': '203648',
#   'teamId': '1610612749',
#   'jersey': '',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '7',
#   'heightMeters': '2.01',
#   'weightPounds': '205',
#   'weightKilograms': '93.0',
#   'dateOfBirthUTC': '1992-07-18',
#   'teamSitesOnly': {'playerCode': 'thanasis_antetokounmpo',
#    'posFull': 'Forward',
#    'displayAffiliation': 'Greece',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612752',
#     'seasonStart': '2015',
#     'seasonEnd': '2015'},
#    {'teamId': '1610612749', 'seasonStart': '2019', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612752',
#    'pickNum': '51',
#    'roundNum': '2',
#    'seasonYear': '2014'},
#   'nbaDebutYear': '2015',
#   'yearsPro': '1',
#   'collegeName': ' ',
#   'lastAffiliation': ' Greece/Greece',
#   'country': 'Greece'},
#  {'firstName': 'OG',
#   'lastName': 'Anunoby',
#   'temporaryDisplayName': 'Anunoby, OG',
#   'personId': '1628384',
#   'teamId': '1610612761',
#   'jersey': '3',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '8',
#   'heightMeters': '2.03',
#   'weightPounds': '232',
#   'weightKilograms': '105.2',
#   'dateOfBirthUTC': '1997-07-17',
#   'teamSitesOnly': {'playerCode': 'og_anunoby',
#    'posFull': 'Forward',
#    'displayAffiliation': 'Indiana/England',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612761',
#     'seasonStart': '2017',
#     'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612761',
#    'pickNum': '23',
#    'roundNum': '1',
#    'seasonYear': '2017'},
#   'nbaDebutYear': '2017',
#   'yearsPro': '2',
#   'collegeName': 'Indiana',
#   'lastAffiliation': 'Indiana/United Kingdom',
#   'country': 'United Kingdom'},
#  {'firstName': 'Ryan',
#   'lastName': 'Arcidiacono',
#   'temporaryDisplayName': 'Arcidiacono, Ryan',
#   'personId': '1627853',
#   'teamId': '1610612741',
#   'jersey': '51',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '3',
#   'heightMeters': '1.9',
#   'weightPounds': '208',
#   'weightKilograms': '94.3',
#   'dateOfBirthUTC': '1994-03-26',
#   'teamSitesOnly': {'playerCode': 'ryan_arcidiacono',
#    'posFull': 'Guard',
#    'displayAffiliation': 'Villanova/USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612741',
#     'seasonStart': '2017',
#     'seasonEnd': '2019'}],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '2017',
#   'yearsPro': '2',
#   'collegeName': 'Villanova',
#   'lastAffiliation': 'Villanova/USA',
#   'country': 'USA'},
#  {'firstName': 'Trevor',
#   'lastName': 'Ariza',
#   'temporaryDisplayName': 'Ariza, Trevor',
#   'personId': '2772',
#   'teamId': '1610612758',
#   'jersey': '0',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '8',
#   'heightMeters': '2.03',
#   'weightPounds': '215',
#   'weightKilograms': '97.5',
#   'dateOfBirthUTC': '1985-06-30',
#   'teamSitesOnly': {'playerCode': 'trevor_ariza',
#    'posFull': 'Forward',
#    'displayAffiliation': 'UCLA/USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612752',
#     'seasonStart': '2004',
#     'seasonEnd': '2005'},
#    {'teamId': '1610612753', 'seasonStart': '2005', 'seasonEnd': '2007'},
#    {'teamId': '1610612747', 'seasonStart': '2007', 'seasonEnd': '2008'},
#    {'teamId': '1610612745', 'seasonStart': '2009', 'seasonEnd': '2009'},
#    {'teamId': '1610612740', 'seasonStart': '2010', 'seasonEnd': '2011'},
#    {'teamId': '1610612764', 'seasonStart': '2012', 'seasonEnd': '2013'},
#    {'teamId': '1610612745', 'seasonStart': '2014', 'seasonEnd': '2017'},
#    {'teamId': '1610612756', 'seasonStart': '2018', 'seasonEnd': '2018'},
#    {'teamId': '1610612764', 'seasonStart': '2018', 'seasonEnd': '2018'},
#    {'teamId': '1610612758', 'seasonStart': '2019', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612752',
#    'pickNum': '43',
#    'roundNum': '2',
#    'seasonYear': '2004'},
#   'nbaDebutYear': '2004',
#   'yearsPro': '15',
#   'collegeName': 'UCLA',
#   'lastAffiliation': 'UCLA/USA',
#   'country': 'USA'},
#  {'firstName': 'D.J.',
#   'lastName': 'Augustin',
#   'temporaryDisplayName': 'Augustin, D.J.',
#   'personId': '201571',
#   'teamId': '1610612753',
#   'jersey': '14',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '0',
#   'heightMeters': '1.83',
#   'weightPounds': '183',
#   'weightKilograms': '83.0',
#   'dateOfBirthUTC': '1987-11-10',
#   'teamSitesOnly': {'playerCode': 'd.j._augustin',
#    'posFull': 'Guard',
#    'displayAffiliation': 'Texas/USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612766',
#     'seasonStart': '2008',
#     'seasonEnd': '2011'},
#    {'teamId': '1610612754', 'seasonStart': '2012', 'seasonEnd': '2012'},
#    {'teamId': '1610612741', 'seasonStart': '2013', 'seasonEnd': '2013'},
#    {'teamId': '1610612761', 'seasonStart': '2013', 'seasonEnd': '2013'},
#    {'teamId': '1610612765', 'seasonStart': '2014', 'seasonEnd': '2014'},
#    {'teamId': '1610612760', 'seasonStart': '2014', 'seasonEnd': '2015'},
#    {'teamId': '1610612743', 'seasonStart': '2015', 'seasonEnd': '2015'},
#    {'teamId': '1610612753', 'seasonStart': '2016', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612766',
#    'pickNum': '9',
#    'roundNum': '1',
#    'seasonYear': '2008'},
#   'nbaDebutYear': '2008',
#   'yearsPro': '11',
#   'collegeName': 'Texas',
#   'lastAffiliation': 'Texas/USA',
#   'country': 'USA'},
#  {'firstName': 'Deandre',
#   'lastName': 'Ayton',
#   'temporaryDisplayName': 'Ayton, Deandre',
#   'personId': '1629028',
#   'teamId': '1610612756',
#   'jersey': '22',
#   'isActive': True,
#   'pos': 'C',
#   'heightFeet': '7',
#   'heightInches': '1',
#   'heightMeters': '2.16',
#   'weightPounds': '250',
#   'weightKilograms': '113.4',
#   'dateOfBirthUTC': '1998-07-23',
#   'teamSitesOnly': {'playerCode': 'deandre_ayton',
#    'posFull': 'Center',
#    'displayAffiliation': 'Arizona/Bahamas',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612756',
#     'seasonStart': '2018',
#     'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612756',
#    'pickNum': '1',
#    'roundNum': '1',
#    'seasonYear': '2018'},
#   'nbaDebutYear': '2018',
#   'yearsPro': '1',
#   'collegeName': 'Arizona',
#   'lastAffiliation': 'University of Arizona/Bahamas',
#   'country': 'Bahamas'},
#  {'firstName': 'Dwayne',
#   'lastName': 'Bacon',
#   'temporaryDisplayName': 'Bacon, Dwayne',
#   'personId': '1628407',
#   'teamId': '1610612766',
#   'jersey': '7',
#   'isActive': True,
#   'pos': 'G-F',
#   'heightFeet': '6',
#   'heightInches': '7',
#   'heightMeters': '2.01',
#   'weightPounds': '221',
#   'weightKilograms': '100.2',
#   'dateOfBirthUTC': '1995-08-30',
#   'teamSitesOnly': {'playerCode': 'dwayne_bacon',
#    'posFull': 'Guard-Forward',
#    'displayAffiliation': 'Florida State/USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612766',
#     'seasonStart': '2017',
#     'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612740',
#    'pickNum': '40',
#    'roundNum': '2',
#    'seasonYear': '2017'},
#   'nbaDebutYear': '2017',
#   'yearsPro': '2',
#   'collegeName': 'Florida State',
#   'lastAffiliation': 'Florida State/USA',
#   'country': 'USA'},
#  {'firstName': 'Marvin',
#   'lastName': 'Bagley III',
#   'temporaryDisplayName': 'Bagley III, Marvin',
#   'personId': '1628963',
#   'teamId': '1610612758',
#   'jersey': '35',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '11',
#   'heightMeters': '2.11',
#   'weightPounds': '240',
#   'weightKilograms': '108.9',
#   'dateOfBirthUTC': '1999-03-14',
#   'teamSitesOnly': {'playerCode': 'marvin_bagley_iii',
#    'posFull': 'Forward',
#    'displayAffiliation': 'Duke/USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612758',
#     'seasonStart': '2018',
#     'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612758',
#    'pickNum': '2',
#    'roundNum': '1',
#    'seasonYear': '2018'},
#   'nbaDebutYear': '2018',
#   'yearsPro': '1',
#   'collegeName': 'Duke',
#   'lastAffiliation': 'Duke University/USA',
#   'country': 'USA'},
#  {'firstName': 'Lonzo',
#   'lastName': 'Ball',
#   'temporaryDisplayName': 'Ball, Lonzo',
#   'personId': '1628366',
#   'teamId': '1610612740',
#   'jersey': '2',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '6',
#   'heightMeters': '1.98',
#   'weightPounds': '190',
#   'weightKilograms': '86.2',
#   'dateOfBirthUTC': '1997-10-27',
#   'teamSitesOnly': {'playerCode': 'lonzo_ball',
#    'posFull': 'Guard',
#    'displayAffiliation': 'UCLA/USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612747',
#     'seasonStart': '2017',
#     'seasonEnd': '2018'},
#    {'teamId': '1610612740', 'seasonStart': '2019', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612747',
#    'pickNum': '2',
#    'roundNum': '1',
#    'seasonYear': '2017'},
#   'nbaDebutYear': '2017',
#   'yearsPro': '2',
#   'collegeName': 'UCLA',
#   'lastAffiliation': 'UCLA/USA',
#   'country': 'USA'},
#  {'firstName': 'Mo',
#   'lastName': 'Bamba',
#   'temporaryDisplayName': 'Bamba, Mo',
#   'personId': '1628964',
#   'teamId': '1610612753',
#   'jersey': '5',
#   'isActive': True,
#   'pos': 'C',
#   'heightFeet': '7',
#   'heightInches': '1',
#   'heightMeters': '2.16',
#   'weightPounds': '241',
#   'weightKilograms': '109.3',
#   'dateOfBirthUTC': '1998-05-12',
#   'teamSitesOnly': {'playerCode': 'mohamed_bamba',
#    'posFull': 'Center',
#    'displayAffiliation': 'Texas/USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612753',
#     'seasonStart': '2018',
#     'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612753',
#    'pickNum': '6',
#    'roundNum': '1',
#    'seasonYear': '2018'},
#   'nbaDebutYear': '2018',
#   'yearsPro': '1',
#   'collegeName': 'University of Texas at Austin',
#   'lastAffiliation': 'University of Texas at Austin/USA',
#   'country': 'USA'},
#  {'firstName': 'J.J.',
#   'lastName': 'Barea',
#   'temporaryDisplayName': 'Barea, J.J.',
#   'personId': '200826',
#   'teamId': '1610612742',
#   'jersey': '5',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '0',
#   'heightMeters': '1.83',
#   'weightPounds': '185',
#   'weightKilograms': '83.9',
#   'dateOfBirthUTC': '1984-06-26',
#   'teamSitesOnly': {'playerCode': 'j.j._barea',
#    'posFull': 'Guard',
#    'displayAffiliation': 'Northeastern/Puerto Rico',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612742',
#     'seasonStart': '2006',
#     'seasonEnd': '2010'},
#    {'teamId': '1610612750', 'seasonStart': '2011', 'seasonEnd': '2013'},
#    {'teamId': '1610612742', 'seasonStart': '2014', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '2006',
#   'yearsPro': '13',
#   'collegeName': 'Northeastern',
#   'lastAffiliation': 'Northeastern/Puerto Rico',
#   'country': 'Puerto Rico'},
#  {'firstName': 'Harrison',
#   'lastName': 'Barnes',
#   'temporaryDisplayName': 'Barnes, Harrison',
#   'personId': '203084',
#   'teamId': '1610612758',
#   'jersey': '40',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '8',
#   'heightMeters': '2.03',
#   'weightPounds': '225',
#   'weightKilograms': '102.1',
#   'dateOfBirthUTC': '1992-05-30',
#   'teamSitesOnly': {'playerCode': 'harrison_barnes',
#    'posFull': 'Forward',
#    'displayAffiliation': 'North Carolina/USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612744',
#     'seasonStart': '2012',
#     'seasonEnd': '2015'},
#    {'teamId': '1610612742', 'seasonStart': '2016', 'seasonEnd': '2018'},
#    {'teamId': '1610612758', 'seasonStart': '2018', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612744',
#    'pickNum': '7',
#    'roundNum': '1',
#    'seasonYear': '2012'},
#   'nbaDebutYear': '2012',
#   'yearsPro': '7',
#   'collegeName': 'North Carolina',
#   'lastAffiliation': 'North Carolina/USA',
#   'country': 'USA'},
#  {'firstName': 'RJ',
#   'lastName': 'Barrett',
#   'temporaryDisplayName': 'Barrett, RJ',
#   'personId': '1629628',
#   'teamId': '1610612752',
#   'jersey': '9',
#   'isActive': True,
#   'pos': 'F-G',
#   'heightFeet': '6',
#   'heightInches': '7',
#   'heightMeters': '2.01',
#   'weightPounds': '202',
#   'weightKilograms': '91.6',
#   'dateOfBirthUTC': '2000-06-14',
#   'teamSitesOnly': {'playerCode': 'rj_barrett',
#    'posFull': 'Forward-Guard',
#    'displayAffiliation': 'Duke/Canada',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612752',
#     'seasonStart': '2019',
#     'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612752',
#    'pickNum': '3',
#    'roundNum': '1',
#    'seasonYear': '2019'},
#   'nbaDebutYear': '',
#   'yearsPro': '0',
#   'collegeName': 'Duke',
#   'lastAffiliation': ' Canada/Canada',
#   'country': 'Canada'},
#  {'firstName': 'Will',
#   'lastName': 'Barton',
#   'temporaryDisplayName': 'Barton, Will',
#   'personId': '203115',
#   'teamId': '1610612743',
#   'jersey': '5',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '6',
#   'heightMeters': '1.98',
#   'weightPounds': '190',
#   'weightKilograms': '86.2',
#   'dateOfBirthUTC': '1991-01-06',
#   'teamSitesOnly': {'playerCode': 'will_barton',
#    'posFull': 'Guard',
#    'displayAffiliation': 'Memphis/USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612757',
#     'seasonStart': '2012',
#     'seasonEnd': '2014'},
#    {'teamId': '1610612743', 'seasonStart': '2014', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612757',
#    'pickNum': '40',
#    'roundNum': '2',
#    'seasonYear': '2012'},
#   'nbaDebutYear': '2012',
#   'yearsPro': '7',
#   'collegeName': 'Memphis',
#   'lastAffiliation': 'Memphis/USA',
#   'country': 'USA'},
#  {'firstName': 'Keita',
#   'lastName': 'Bates-Diop',
#   'temporaryDisplayName': 'Bates-Diop, Keita',
#   'personId': '1628966',
#   'teamId': '1610612750',
#   'jersey': '31',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '9',
#   'heightMeters': '2.06',
#   'weightPounds': '229',
#   'weightKilograms': '103.9',
#   'dateOfBirthUTC': '1996-01-23',
#   'teamSitesOnly': {'playerCode': 'keita_bates-diop',
#    'posFull': 'Forward',
#    'displayAffiliation': 'Ohio State/USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612750',
#     'seasonStart': '2018',
#     'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612750',
#    'pickNum': '48',
#    'roundNum': '2',
#    'seasonYear': '2018'},
#   'nbaDebutYear': '2018',
#   'yearsPro': '1',
#   'collegeName': 'Ohio State',
#   'lastAffiliation': 'Ohio State University/USA',
#   'country': 'USA'},
#  {'firstName': 'Nicolas',
#   'lastName': 'Batum',
#   'temporaryDisplayName': 'Batum, Nicolas',
#   'personId': '201587',
#   'teamId': '1610612766',
#   'jersey': '5',
#   'isActive': True,
#   'pos': 'G-F',
#   'heightFeet': '6',
#   'heightInches': '8',
#   'heightMeters': '2.03',
#   'weightPounds': '200',
#   'weightKilograms': '90.7',
#   'dateOfBirthUTC': '1988-12-14',
#   'teamSitesOnly': {'playerCode': 'nicolas_batum',
#    'posFull': 'Guard-Forward',
#    'displayAffiliation': 'Le Mans/France',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612757',
#     'seasonStart': '2008',
#     'seasonEnd': '2014'},
#    {'teamId': '1610612766', 'seasonStart': '2015', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612745',
#    'pickNum': '25',
#    'roundNum': '1',
#    'seasonYear': '2008'},
#   'nbaDebutYear': '2008',
#   'yearsPro': '11',
#   'collegeName': ' ',
#   'lastAffiliation': 'Le Mans/France',
#   'country': 'France'},
#  {'firstName': 'Aron',
#   'lastName': 'Baynes',
#   'temporaryDisplayName': 'Baynes, Aron',
#   'personId': '203382',
#   'teamId': '1610612756',
#   'jersey': '46',
#   'isActive': True,
#   'pos': 'C',
#   'heightFeet': '6',
#   'heightInches': '10',
#   'heightMeters': '2.08',
#   'weightPounds': '260',
#   'weightKilograms': '117.9',
#   'dateOfBirthUTC': '1986-12-09',
#   'teamSitesOnly': {'playerCode': 'aron_baynes',
#    'posFull': 'Center',
#    'displayAffiliation': 'Washington State/Australia',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612759',
#     'seasonStart': '2012',
#     'seasonEnd': '2014'},
#    {'teamId': '1610612765', 'seasonStart': '2015', 'seasonEnd': '2016'},
#    {'teamId': '1610612738', 'seasonStart': '2017', 'seasonEnd': '2018'},
#    {'teamId': '1610612756', 'seasonStart': '2019', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '2012',
#   'yearsPro': '7',
#   'collegeName': 'Washington State',
#   'lastAffiliation': 'Washington State/Australia',
#   'country': 'Australia'},
#  {'firstName': 'Kent',
#   'lastName': 'Bazemore',
#   'temporaryDisplayName': 'Bazemore, Kent',
#   'personId': '203145',
#   'teamId': '1610612757',
#   'jersey': '24',
#   'isActive': True,
#   'pos': 'G-F',
#   'heightFeet': '6',
#   'heightInches': '5',
#   'heightMeters': '1.96',
#   'weightPounds': '200',
#   'weightKilograms': '90.7',
#   'dateOfBirthUTC': '1989-07-01',
#   'teamSitesOnly': {'playerCode': 'kent_bazemore',
#    'posFull': 'Guard-Forward',
#    'displayAffiliation': 'Old Dominion/USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612744',
#     'seasonStart': '2012',
#     'seasonEnd': '2013'},
#    {'teamId': '1610612747', 'seasonStart': '2013', 'seasonEnd': '2013'},
#    {'teamId': '1610612737', 'seasonStart': '2014', 'seasonEnd': '2018'},
#    {'teamId': '1610612757', 'seasonStart': '2019', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '2012',
#   'yearsPro': '7',
#   'collegeName': 'Old Dominion',
#   'lastAffiliation': 'Old Dominion/USA',
#   'country': 'USA'},
#  {'firstName': 'Darius',
#   'lastName': 'Bazley',
#   'temporaryDisplayName': 'Bazley, Darius',
#   'personId': '1629647',
#   'teamId': '1610612760',
#   'jersey': '7',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '8',
#   'heightMeters': '2.03',
#   'weightPounds': '208',
#   'weightKilograms': '94.3',
#   'dateOfBirthUTC': '2000-06-12',
#   'teamSitesOnly': {'playerCode': 'darius_bazley',
#    'posFull': 'Forward',
#    'displayAffiliation': 'USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612760',
#     'seasonStart': '2019',
#     'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612762',
#    'pickNum': '23',
#    'roundNum': '1',
#    'seasonYear': '2019'},
#   'nbaDebutYear': '',
#   'yearsPro': '0',
#   'collegeName': ' ',
#   'lastAffiliation': ' USA/USA',
#   'country': 'USA'},
#  {'firstName': 'Bradley',
#   'lastName': 'Beal',
#   'temporaryDisplayName': 'Beal, Bradley',
#   'personId': '203078',
#   'teamId': '1610612764',
#   'jersey': '3',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '5',
#   'heightMeters': '1.96',
#   'weightPounds': '207',
#   'weightKilograms': '93.9',
#   'dateOfBirthUTC': '1993-06-28',
#   'teamSitesOnly': {'playerCode': 'bradley_beal',
#    'posFull': 'Guard',
#    'displayAffiliation': 'Florida/USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612764',
#     'seasonStart': '2012',
#     'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612764',
#    'pickNum': '3',
#    'roundNum': '1',
#    'seasonYear': '2012'},
#   'nbaDebutYear': '2012',
#   'yearsPro': '7',
#   'collegeName': 'Florida',
#   'lastAffiliation': 'Florida/USA',
#   'country': 'USA'},
#  {'firstName': 'Malik',
#   'lastName': 'Beasley',
#   'temporaryDisplayName': 'Beasley, Malik',
#   'personId': '1627736',
#   'teamId': '1610612743',
#   'jersey': '25',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '5',
#   'heightMeters': '1.96',
#   'weightPounds': '195',
#   'weightKilograms': '88.5',
#   'dateOfBirthUTC': '1996-11-26',
#   'teamSitesOnly': {'playerCode': 'malik_beasley',
#    'posFull': 'Guard',
#    'displayAffiliation': 'Florida State/USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612743',
#     'seasonStart': '2016',
#     'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612743',
#    'pickNum': '19',
#    'roundNum': '1',
#    'seasonYear': '2016'},
#   'nbaDebutYear': '2016',
#   'yearsPro': '3',
#   'collegeName': 'Florida State',
#   'lastAffiliation': 'Florida State/USA',
#   'country': 'USA'},
#  {'firstName': 'Marco',
#   'lastName': 'Belinelli',
#   'temporaryDisplayName': 'Belinelli, Marco',
#   'personId': '201158',
#   'teamId': '1610612759',
#   'jersey': '18',
#   'isActive': True,
#   'pos': 'G-F',
#   'heightFeet': '6',
#   'heightInches': '5',
#   'heightMeters': '1.96',
#   'weightPounds': '210',
#   'weightKilograms': '95.3',
#   'dateOfBirthUTC': '1986-03-25',
#   'teamSitesOnly': {'playerCode': 'marco_belinelli',
#    'posFull': 'Guard-Forward',
#    'displayAffiliation': 'Fortitudo Bologna/Italy',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612744',
#     'seasonStart': '2007',
#     'seasonEnd': '2008'},
#    {'teamId': '1610612761', 'seasonStart': '2009', 'seasonEnd': '2009'},
#    {'teamId': '1610612740', 'seasonStart': '2010', 'seasonEnd': '2011'},
#    {'teamId': '1610612741', 'seasonStart': '2012', 'seasonEnd': '2012'},
#    {'teamId': '1610612759', 'seasonStart': '2013', 'seasonEnd': '2014'},
#    {'teamId': '1610612758', 'seasonStart': '2015', 'seasonEnd': '2015'},
#    {'teamId': '1610612766', 'seasonStart': '2016', 'seasonEnd': '2016'},
#    {'teamId': '1610612755', 'seasonStart': '2017', 'seasonEnd': '2017'},
#    {'teamId': '1610612737', 'seasonStart': '2017', 'seasonEnd': '2017'},
#    {'teamId': '1610612759', 'seasonStart': '2018', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612744',
#    'pickNum': '18',
#    'roundNum': '1',
#    'seasonYear': '2007'},
#   'nbaDebutYear': '2007',
#   'yearsPro': '12',
#   'collegeName': ' ',
#   'lastAffiliation': 'Fortitudo Bologna/Italy',
#   'country': 'Italy'},
#  {'firstName': 'Jordan',
#   'lastName': 'Bell',
#   'temporaryDisplayName': 'Bell, Jordan',
#   'personId': '1628395',
#   'teamId': '1610612750',
#   'jersey': '',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '9',
#   'heightMeters': '2.06',
#   'weightPounds': '224',
#   'weightKilograms': '101.6',
#   'dateOfBirthUTC': '1995-01-07',
#   'teamSitesOnly': {'playerCode': 'jordan_bell',
#    'posFull': 'Forward',
#    'displayAffiliation': 'Oregon/USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612744',
#     'seasonStart': '2017',
#     'seasonEnd': '2018'},
#    {'teamId': '1610612750', 'seasonStart': '2019', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612741',
#    'pickNum': '38',
#    'roundNum': '2',
#    'seasonYear': '2017'},
#   'nbaDebutYear': '2017',
#   'yearsPro': '2',
#   'collegeName': 'Oregon',
#   'lastAffiliation': 'Oregon/USA',
#   'country': 'USA'},
#  {'firstName': "DeAndre'",
#   'lastName': 'Bembry',
#   'temporaryDisplayName': "Bembry, DeAndre'",
#   'personId': '1627761',
#   'teamId': '1610612737',
#   'jersey': '95',
#   'isActive': True,
#   'pos': 'G-F',
#   'heightFeet': '6',
#   'heightInches': '6',
#   'heightMeters': '1.98',
#   'weightPounds': '210',
#   'weightKilograms': '95.3',
#   'dateOfBirthUTC': '1994-07-04',
#   'teamSitesOnly': {'playerCode': "deandre'_bembry",
#    'posFull': 'Guard-Forward',
#    'displayAffiliation': "St. Joseph's (PA)/USA",
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612737',
#     'seasonStart': '2016',
#     'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612737',
#    'pickNum': '21',
#    'roundNum': '1',
#    'seasonYear': '2016'},
#   'nbaDebutYear': '2016',
#   'yearsPro': '3',
#   'collegeName': "St. Joseph's, PA",
#   'lastAffiliation': "St. Joseph's (PA)/USA",
#   'country': 'USA'},
#  {'firstName': 'Dragan',
#   'lastName': 'Bender',
#   'temporaryDisplayName': 'Bender, Dragan',
#   'personId': '1627733',
#   'teamId': '1610612749',
#   'jersey': '',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '7',
#   'heightInches': '1',
#   'heightMeters': '2.16',
#   'weightPounds': '225',
#   'weightKilograms': '102.1',
#   'dateOfBirthUTC': '1997-11-17',
#   'teamSitesOnly': {'playerCode': 'dragan_bender',
#    'posFull': 'Forward',
#    'displayAffiliation': 'Maccabi Tel Aviv/Croatia',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612756',
#     'seasonStart': '2016',
#     'seasonEnd': '2018'},
#    {'teamId': '1610612749', 'seasonStart': '2019', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612756',
#    'pickNum': '4',
#    'roundNum': '1',
#    'seasonYear': '2016'},
#   'nbaDebutYear': '2016',
#   'yearsPro': '3',
#   'collegeName': ' ',
#   'lastAffiliation': 'Croatia/Croatia',
#   'country': 'Croatia'},
#  {'firstName': 'Anthony',
#   'lastName': 'Bennett',
#   'temporaryDisplayName': 'Bennett, Anthony',
#   'personId': '203461',
#   'teamId': '1610612745',
#   'jersey': '30',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '8',
#   'heightMeters': '2.03',
#   'weightPounds': '245',
#   'weightKilograms': '111.1',
#   'dateOfBirthUTC': '1993-03-14',
#   'teamSitesOnly': {'playerCode': 'anthony_bennett',
#    'posFull': 'Forward',
#    'displayAffiliation': 'Nevada-Las Vegas/Canada',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612739',
#     'seasonStart': '2013',
#     'seasonEnd': '2013'},
#    {'teamId': '1610612750', 'seasonStart': '2014', 'seasonEnd': '2014'},
#    {'teamId': '1610612761', 'seasonStart': '2015', 'seasonEnd': '2015'},
#    {'teamId': '1610612751', 'seasonStart': '2016', 'seasonEnd': '2016'},
#    {'teamId': '1610612745', 'seasonStart': '2019', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612739',
#    'pickNum': '1',
#    'roundNum': '1',
#    'seasonYear': '2013'},
#   'nbaDebutYear': '2013',
#   'yearsPro': '4',
#   'collegeName': 'UNLV',
#   'lastAffiliation': 'Nevada-Las Vegas/Canada',
#   'country': 'Canada'},
#  {'firstName': 'Davis',
#   'lastName': 'Bertans',
#   'temporaryDisplayName': 'Bertans, Davis',
#   'personId': '202722',
#   'teamId': '1610612764',
#   'jersey': '42',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '10',
#   'heightMeters': '2.08',
#   'weightPounds': '225',
#   'weightKilograms': '102.1',
#   'dateOfBirthUTC': '1992-11-12',
#   'teamSitesOnly': {'playerCode': 'davis_bertans',
#    'posFull': 'Forward',
#    'displayAffiliation': 'Laboral Kutxa (Spain)/Latvia',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612759',
#     'seasonStart': '2016',
#     'seasonEnd': '2018'},
#    {'teamId': '1610612764', 'seasonStart': '2019', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612754',
#    'pickNum': '42',
#    'roundNum': '2',
#    'seasonYear': '2011'},
#   'nbaDebutYear': '2016',
#   'yearsPro': '3',
#   'collegeName': ' ',
#   'lastAffiliation': ' Latvia/Latvia',
#   'country': 'Latvia'},
#  {'firstName': 'Javon',
#   'lastName': 'Bess',
#   'temporaryDisplayName': 'Bess, Javon',
#   'personId': '1629715',
#   'teamId': '1610612740',
#   'jersey': '9',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '6',
#   'heightMeters': '1.98',
#   'weightPounds': '220',
#   'weightKilograms': '99.8',
#   'dateOfBirthUTC': '1996-04-01',
#   'teamSitesOnly': {'playerCode': 'javon_bess',
#    'posFull': 'Guard',
#    'displayAffiliation': 'St. Louis',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612740',
#     'seasonStart': '2019',
#     'seasonEnd': '2019'}],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '0',
#   'collegeName': 'St. Louis',
#   'lastAffiliation': 'Saint Louis University/USA',
#   'country': 'USA'},
#  {'firstName': 'Patrick',
#   'lastName': 'Beverley',
#   'temporaryDisplayName': 'Beverley, Patrick',
#   'personId': '201976',
#   'teamId': '1610612746',
#   'jersey': '21',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '1',
#   'heightMeters': '1.85',
#   'weightPounds': '185',
#   'weightKilograms': '83.9',
#   'dateOfBirthUTC': '1988-07-12',
#   'teamSitesOnly': {'playerCode': 'patrick_beverley',
#    'posFull': 'Guard',
#    'displayAffiliation': 'Arkansas/USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612745',
#     'seasonStart': '2012',
#     'seasonEnd': '2016'},
#    {'teamId': '1610612746', 'seasonStart': '2017', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612747',
#    'pickNum': '42',
#    'roundNum': '2',
#    'seasonYear': '2009'},
#   'nbaDebutYear': '2012',
#   'yearsPro': '7',
#   'collegeName': 'Arkansas',
#   'lastAffiliation': 'Arkansas/USA',
#   'country': 'USA'},
#  {'firstName': 'Kavell',
#   'lastName': 'Bigby-Williams',
#   'temporaryDisplayName': 'Bigby-Williams, Kavell',
#   'personId': '1628448',
#   'teamId': '1610612740',
#   'jersey': '13',
#   'isActive': True,
#   'pos': 'C',
#   'heightFeet': '6',
#   'heightInches': '11',
#   'heightMeters': '2.11',
#   'weightPounds': '250',
#   'weightKilograms': '113.4',
#   'dateOfBirthUTC': '1995-10-07',
#   'teamSitesOnly': {'playerCode': 'kavell_bigby-williams',
#    'posFull': 'Center',
#    'displayAffiliation': 'Louisiana State/England',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612740',
#     'seasonStart': '2019',
#     'seasonEnd': '2019'}],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '0',
#   'collegeName': 'Louisiana State',
#   'lastAffiliation': ' /United Kingdom',
#   'country': 'United Kingdom'},
#  {'firstName': 'Khem',
#   'lastName': 'Birch',
#   'temporaryDisplayName': 'Birch, Khem',
#   'personId': '203920',
#   'teamId': '1610612753',
#   'jersey': '24',
#   'isActive': True,
#   'pos': 'C',
#   'heightFeet': '6',
#   'heightInches': '9',
#   'heightMeters': '2.06',
#   'weightPounds': '233',
#   'weightKilograms': '105.7',
#   'dateOfBirthUTC': '1992-09-28',
#   'teamSitesOnly': {'playerCode': 'khem_birch',
#    'posFull': 'Center',
#    'displayAffiliation': 'Nevada-Las Vegas/Canada',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612753',
#     'seasonStart': '2017',
#     'seasonEnd': '2019'}],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '2017',
#   'yearsPro': '2',
#   'collegeName': 'UNLV',
#   'lastAffiliation': 'Nevada-Las Vegas/Canada',
#   'country': 'Canada'},
#  {'firstName': 'Goga',
#   'lastName': 'Bitadze',
#   'temporaryDisplayName': 'Bitadze, Goga',
#   'personId': '1629048',
#   'teamId': '1610612754',
#   'jersey': '88',
#   'isActive': True,
#   'pos': 'C',
#   'heightFeet': '6',
#   'heightInches': '11',
#   'heightMeters': '2.11',
#   'weightPounds': '245',
#   'weightKilograms': '111.1',
#   'dateOfBirthUTC': '1999-07-20',
#   'teamSitesOnly': {'playerCode': 'goga_bitadze',
#    'posFull': 'Center',
#    'displayAffiliation': 'Georgia',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612754',
#     'seasonStart': '2019',
#     'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612754',
#    'pickNum': '18',
#    'roundNum': '1',
#    'seasonYear': '2019'},
#   'nbaDebutYear': '',
#   'yearsPro': '0',
#   'collegeName': ' ',
#   'lastAffiliation': ' Georgia/Georgia',
#   'country': 'Georgia'},
#  {'firstName': 'Bismack',
#   'lastName': 'Biyombo',
#   'temporaryDisplayName': 'Biyombo, Bismack',
#   'personId': '202687',
#   'teamId': '1610612766',
#   'jersey': '8',
#   'isActive': True,
#   'pos': 'C',
#   'heightFeet': '6',
#   'heightInches': '9',
#   'heightMeters': '2.06',
#   'weightPounds': '255',
#   'weightKilograms': '115.7',
#   'dateOfBirthUTC': '1992-08-28',
#   'teamSitesOnly': {'playerCode': 'bismack_biyombo',
#    'posFull': 'Center',
#    'displayAffiliation': 'Baloncesto Fuenlabrada/DRC',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612766',
#     'seasonStart': '2011',
#     'seasonEnd': '2014'},
#    {'teamId': '1610612761', 'seasonStart': '2015', 'seasonEnd': '2015'},
#    {'teamId': '1610612753', 'seasonStart': '2016', 'seasonEnd': '2017'},
#    {'teamId': '1610612766', 'seasonStart': '2018', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612758',
#    'pickNum': '7',
#    'roundNum': '1',
#    'seasonYear': '2011'},
#   'nbaDebutYear': '2011',
#   'yearsPro': '8',
#   'collegeName': ' ',
#   'lastAffiliation': 'Baloncesto Fuenlabrada/Democratic Republic of Cong',
#   'country': 'Democratic Republic of the Congo'},
#  {'firstName': 'Nemanja',
#   'lastName': 'Bjelica',
#   'temporaryDisplayName': 'Bjelica, Nemanja',
#   'personId': '202357',
#   'teamId': '1610612758',
#   'jersey': '88',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '10',
#   'heightMeters': '2.08',
#   'weightPounds': '235',
#   'weightKilograms': '106.6',
#   'dateOfBirthUTC': '1988-05-09',
#   'teamSitesOnly': {'playerCode': 'nemanja_bjelica',
#    'posFull': 'Forward',
#    'displayAffiliation': 'Fenerbahce Ulker/Serbia',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612750',
#     'seasonStart': '2015',
#     'seasonEnd': '2017'},
#    {'teamId': '1610612758', 'seasonStart': '2018', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612764',
#    'pickNum': '35',
#    'roundNum': '2',
#    'seasonYear': '2010'},
#   'nbaDebutYear': '2015',
#   'yearsPro': '4',
#   'collegeName': ' ',
#   'lastAffiliation': 'Fenerbahce Ulker/Serbia',
#   'country': 'Serbia'},
#  {'firstName': 'Eric',
#   'lastName': 'Bledsoe',
#   'temporaryDisplayName': 'Bledsoe, Eric',
#   'personId': '202339',
#   'teamId': '1610612749',
#   'jersey': '6',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '1',
#   'heightMeters': '1.85',
#   'weightPounds': '205',
#   'weightKilograms': '93.0',
#   'dateOfBirthUTC': '1989-12-09',
#   'teamSitesOnly': {'playerCode': 'eric_bledsoe',
#    'posFull': 'Guard',
#    'displayAffiliation': 'Kentucky/USA',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612746',
# ...
#    'pickNum': '23',
#    'roundNum': '1',
#    'seasonYear': '2016'},
#   'nbaDebutYear': '2017',
#   'yearsPro': '2',
#   'collegeName': ' ',
#   'lastAffiliation': 'Croatia/Croatia',
#   'country': 'Croatia'},
#  {'firstName': 'Ivica',
#   'lastName': 'Zubac',
#   'temporaryDisplayName': 'Zubac, Ivica',
#   'personId': '1627826',
#   'teamId': '1610612746',
#   'jersey': '40',
#   'isActive': True,
#   'pos': 'C',
#   'heightFeet': '7',
#   'heightInches': '1',
#   'heightMeters': '2.16',
#   'weightPounds': '240',
#   'weightKilograms': '108.9',
#   'dateOfBirthUTC': '1997-03-18',
#   'teamSitesOnly': {'playerCode': 'ivica_zubac',
#    'posFull': 'Center',
#    'displayAffiliation': 'Bosnia & Herzegovina',
#    'freeAgentCode': ''},
#   'teams': [{'teamId': '1610612747',
#     'seasonStart': '2016',
#     'seasonEnd': '2018'},
#    {'teamId': '1610612746', 'seasonStart': '2018', 'seasonEnd': '2019'}],
#   'draft': {'teamId': '1610612747',
#    'pickNum': '32',
#    'roundNum': '2',
#    'seasonYear': '2016'},
#   'nbaDebutYear': '2016',
#   'yearsPro': '3',
#   'collegeName': ' ',
#   'lastAffiliation': 'Mega Leks/Croatia',
#   'country': 'Croatia'},
#  {'firstName': 'Yuchen',
#   'lastName': 'Shi',
#   'personId': '1962937772',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '11',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Lingyuan',
#   'lastName': 'Meng',
#   'personId': '1966938124',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '5',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Gen',
#   'lastName': 'Li',
#   'personId': '1966938125',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '3',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Chunjun',
#   'lastName': 'Zhang',
#   'personId': '1966938126',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '9',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Yongsheng',
#   'lastName': 'Wu',
#   'personId': '1966938127',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '14',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Qunfei',
#   'lastName': 'Deng',
#   'personId': '1966938128',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '20',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Hanchen',
#   'lastName': 'Luo',
#   'personId': '1966938129',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '33',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Marcio',
#   'lastName': 'Santos',
#   'personId': '1966938131',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '3',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Elio',
#   'lastName': 'Netto',
#   'personId': '1966938132',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '5',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Lucas ',
#   'lastName': 'Dias',
#   'personId': '1966938133',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '9',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Lucas',
#   'lastName': 'Cipolini',
#   'personId': '1966938134',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '15',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Jimmy',
#   'lastName': 'De Oliveira',
#   'personId': '1966938135',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '18',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Carlos',
#   'lastName': 'Schattmann',
#   'personId': '1966938136',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '20',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Luciano',
#   'lastName': 'Parodi',
#   'personId': '1966938137',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '21',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Augusto',
#   'lastName': 'Alcassa',
#   'personId': '1966938138',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '23',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Rafael',
#   'lastName': 'Hettsheimeir',
#   'personId': '1966938139',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '30',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Lucas ',
#   'lastName': 'Batista',
#   'personId': '1966938140',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '31',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'David',
#   'lastName': 'Jackson',
#   'personId': '1966938141',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '32',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Guilherme',
#   'lastName': 'Braga',
#   'personId': '1966938142',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '33',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Donatas',
#   'lastName': 'Motiejunas',
#   'personId': '202700',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '12',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'James',
#   'lastName': 'Nunnally',
#   'personId': '203263',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '21',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Mingxin',
#   'lastName': 'Ju',
#   'personId': '27013',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '24',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Liang',
#   'lastName': 'Cai',
#   'personId': '64091',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '1',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Xu',
#   'lastName': 'Huang',
#   'personId': '64092',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '17',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Zihao',
#   'lastName': 'Tang',
#   'personId': '64094',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '7',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Xudong',
#   'lastName': 'Luo',
#   'personId': '64097',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '13',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Hanlin',
#   'lastName': 'Dong',
#   'personId': '64098',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '10',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Ying',
#   'lastName': 'Zhu',
#   'personId': '64099',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '2',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Zhaoxu',
#   'lastName': 'Zhang',
#   'personId': '64100',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '23',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''},
#  {'firstName': 'Tong',
#   'lastName': 'Wang',
#   'personId': '64101',
#   'isallStar': False,
#   'teamId': '',
#   'jersey': '25',
#   'isActive': False,
#   'pos': '',
#   'heightFeet': '-',
#   'heightInches': '-',
#   'heightMeters': '',
#   'weightPounds': '',
#   'weightKilograms': '',
#   'dateOfBirthUTC': '',
#   'teams': [],
#   'draft': {'teamId': '', 'pickNum': '', 'roundNum': '', 'seasonYear': ''},
#   'nbaDebutYear': '',
#   'yearsPro': '',
#   'collegeName': '',
#   'lastAffiliation': '',
#   'country': ''}]
